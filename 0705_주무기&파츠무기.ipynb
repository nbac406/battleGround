# %%
import pandas as pd

# %%
df = pd.read_csv("./parts_info.csv")
df
# Out:
#         victim_name       victim_weapon  \
# 0   GoonchimSsak-_-                 NaN
# 1         4NineNine       WeapQBZ95_C_6
# 2         DDongpomm         WeapG18_C_0
# 3       eodeoddlsyd        WeapAK47_C_1
# 4        eodeoddlWb       WeapQBZ95_C_7
# ..              ...                 ...
# 89       MINHUYNING  WeapBerylM762_C_19
# 90          ASHdrum    WeapGrenade_C_99
# 91          XackPOT        WeapAUG_C_16
# 92     TTF_SikBBang   WeapBerylM762_C_0
# 93    LE-_CORBUSIER         WeapP90_C_0
#
#                                          victim_parts   killer_name  \
# 0                                                 NaN    HXXYXHXX_-
# 1                                                 NaN      Parkpass
# 2                                                 NaN   HING9_KAMAR
# 3                                                 NaN   HING9_KAMAR
# 4                                                 NaN   HING9_KAMAR
# ...

# %%
df[['victim_weapon', 'victim_parts', 'killer_weapon', 'killer_parts']]
# Out:
#          victim_weapon                                       victim_parts  \
# 0                  NaN                                                NaN
# 1        WeapQBZ95_C_6                                                NaN
# 2          WeapG18_C_0                                                NaN
# 3         WeapAK47_C_1                                                NaN
# 4        WeapQBZ95_C_7                                                NaN
# ..                 ...                                                ...
# 89  WeapBerylM762_C_19  ['Item_Attach_Weapon_Muzzle_Compensator_Large_...
# 90    WeapGrenade_C_99                                                NaN
# 91        WeapAUG_C_16  ['Item_Attach_Weapon_Magazine_ExtendedQuickDra...
# 92   WeapBerylM762_C_0  ['Item_Attach_Weapon_Lower_Foregrip_C', 'Item_...
# 93         WeapP90_C_0                                                NaN
#
#    killer_weapon                                       killer_parts
# ...

# %%
df1 = df['victim_parts'] 
df2 = df['killer_parts']

# %%
df3 = pd.concat([df1, df2], join='outer', axis=0).to_frame()

# %%
for i in df3[0] : 
    if i == 'nan' : 
        pass
    else : 
        print(i)
# Out:
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# ['Item_Attach_Weapon_Lower_Foregrip_C']
# ['Item_Attach_Weapon_Upper_Holosight_C']
# ['Item_Attach_Weapon_Upper_Scope3x_C']
# nan
# ['Item_Attach_Weapon_Lower_LaserPointer_C', 'Item_Attach_Weapon_Stock_AR_Composite_C', 'Item_Attach_Weapon_Muzzle_Suppressor_Large_C']
# nan
# nan
# nan
# nan
# ['Item_Attach_Weapon_Muzzle_Compensator_Medium_C']
# nan
# nan
# ['Item_Attach_Weapon_Muzzle_Compensator_Large_C']
# nan
# nan
# ['Item_Attach_Weapon_Upper_DotSight_01_C', 'Item_Attach_Weapon_Muzzle_FlashHider_Large_C', 'Item_Attach_Weapon_Magazine_Extended_Large_C']
# ['Item_Attach_Weapon_Upper_Holosight_C']
# nan
# ['Item_Attach_Weapon_Upper_Holosight_C', 'Item_Attach_Weapon_Magazine_ExtendedQuickDraw_Large_C', 'Item_Attach_Weapon_Muzzle_Compensator_Large_C']
# ['Item_Attach_Weapon_Upper_ACOG_01_C']
# nan
# ...
