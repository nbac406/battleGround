# %%
import requests

# %%
key = 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJqdGkiOiIxMjg0ZDBjMC1lMGQ5LTAxM2ItNGVlNS0wMjJlZGE2MTJmNmMiLCJpc3MiOiJnYW1lbG9ja2VyIiwiaWF0IjoxNjg1NDI0NjU0LCJwdWIiOiJibHVlaG9sZSIsInRpdGxlIjoicHViZyIsImFwcCI6ImFwaTEifQ.FoLqbKF83KfdOo42OvkoLlswFp78ftcXFeP9akV8R4g'
match_id = "12471124-bec9-423e-8aca-353df6929a76"

# %%
#match_summary 테이블 적재 함수 
from django.shortcuts import render
from .models import Match_summary
import requests

def search_player_match(key, match_id):
    url = f"https://api.pubg.com/shards/steam/matches/{match_id}"
    headers = {
        "Authorization": key,
        "Accept": "application/vnd.api+json"
    }
    response = requests.get(url, headers=headers)
    if response.status_code == 200 : 
        result = response.json()
        for i in range(len(result['included'])) : 
            if result['included'][i]['type'] == 'asset' : 
                matchId = result['data']['id']
                createAt = result['data']['attributes']['createdAt']
                gameMode = result['data']['attributes']['gameMode']
                mapname = result['data']['attributes']['mapName']
                duration = result['data']['attributes']['duration']
                match_type = result['data']['attributes']['matchType']
                asset_url = result['included'][i]['attributes']['URL']
                # match_summary 테이블에 데이터 저장
                match_summary = Match_summary(
                    matchId=matchId,
                    createdAt=createAt,
                    gameMode=gameMode,
                    mapname=mapname,
                    duration=duration,
                    match_type=match_type,
                    asset_url=asset_url
                )
                match_summary.save()

    return render(request, 'template_name.html')

# %%
for i in range(len(result['included'])) : 
    if result['included'][i]['type'] == 'participant' : 
        matchId = result['data']['id']
        player_name = result['included'][i]['attributes']['stats']['name']
        accountId = result['included'][i]['attributes']['stats']['playerId']
        DBNOs = result['included'][i]['attributes']['stats']['DBNOs']
        assists = result['included'][i]['attributes']['stats']['assists']
        damageDealt = result['included'][i]['attributes']['stats']['damageDealt']
        headshotkills = result['included'][i]['attributes']['stats']['headshotKills']
        kills = result['included'][i]['attributes']['stats']['kills']
        longestkill = result['included'][i]['attributes']['stats']['longestKill']
        teamkills = result['included'][i]['attributes']['stats']['teamKills']
        rideDistance = result['included'][i]['attributes']['stats']['rideDistance']
        swimDistance = result['included'][i]['attributes']['stats']['swimDistance']
        walkDistance = result['included'][i]['attributes']['stats']['walkDistance']
        match_participant = match_participant(
            matchId = matchId,
            player_name = player_name,
            accountId = accountId,
            DBNOs = DBNOs,
            assists = assists,
            damageDealt = damageDealt,
            headshotkills = headshotkills,
            kills = kills,
            longestkill = longestkill,
            teamkills = teamkills,
            rideDistance = rideDistance,
            swimDistance = swimDistance,
            walkDistance = walkDistance
        )
        
        match_participant.save()

# %%
result['included'][1]['attributes']['name']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_568\3739124515.py in <module>
# ----> 1 result['included'][1]['attributes']['name']
#
# KeyError: 'name'

# %%
headers = {
        "Authorization": key,
        "Accept": "application/vnd.api+json"
    }

for match_id in match_ids.values() : 
    url = f"https://api.pubg.com/shards/steam/matches/{match_id}"

    response = requests.get(url, headers=headers)

    if response.status_code == 200:
        result = response.json()
        for i in range(len(result['included'])):
            if result['included'][i]['type'] == 'asset':
                matchId = result['data']['id']
                createAt = result['data']['attributes']['createdAt']
                gameMode = result['data']['attributes']['gameMode']
                mapname = result['data']['attributes']['mapName']
                duration = result['data']['attributes']['duration']
                match_type = result['data']['attributes']['matchType']
                asset_url = result['included'][i]['attributes']['URL']
                print(matchId, createAt, gameMode, mapname, duration, match_type, asset_url)

                
            elif result['included'][i]['type'] == 'participant':
                matchId = result['data']['id']
                player_name = result['included'][i]['attributes']['stats']['name']
                accountId = result['included'][i]['attributes']['stats']['playerId']
                DBNOs = result['included'][i]['attributes']['stats']['DBNOs']
                assists = result['included'][i]['attributes']['stats']['assists']
                damageDealt = result['included'][i]['attributes']['stats']['damageDealt']
                headshotkills = result['included'][i]['attributes']['stats']['headshotKills']
                kills = result['included'][i]['attributes']['stats']['kills']
                longestkill = result['included'][i]['attributes']['stats']['longestKill']
                teamkills = result['included'][i]['attributes']['stats']['teamKills']
                rideDistance = result['included'][i]['attributes']['stats']['rideDistance']
                swimDistance = result['included'][i]['attributes']['stats']['swimDistance']
                walkDistance = result['included'][i]['attributes']['stats']['walkDistance']
                
                print(matchId, player_name, accountId, DBNOs, assists, damageDealt, headshotkills, kills, longestkill, teamkills, rideDistance, swimDistance, walkDistance)
# Out:
# c1914d81-0367-4314-a1a8-f36ae62cf9c4 Nv_Lxxxx account.965d742b42d4441c8d44802ca19f889a 0 0 0 0 1 48.371826 0 0 0 835.63245
# c1914d81-0367-4314-a1a8-f36ae62cf9c4 FM_PHOENIX account.942e4bc97d0f40658595d20f36dea0b6 1 1 399.3599 0 1 36.04747 0 2689.068 0 1696.0203
# c1914d81-0367-4314-a1a8-f36ae62cf9c4 horororororok- account.f191f3fad3894ce1b476e3d6b53a5265 0 0 0 0 0 0 0 2015.9598 0 596.3702
# c1914d81-0367-4314-a1a8-f36ae62cf9c4 dflksdfl account.551e0c3c1d6c4483a8409f5027b32776 0 0 106.92897 0 0 0 0 2149.058 0 1421.5426
# c1914d81-0367-4314-a1a8-f36ae62cf9c4 One_FourAll account.8bb0e95deac24540a80917e684c7a8d1 1 0 939.8229 1 3 231.78523 0 2073.7646 0 2006.909
# c1914d81-0367-4314-a1a8-f36ae62cf9c4 AVEC_Q6 account.1ad01021ecff40c09362f6b932b4bc5e 0 0 0 0 0 0 0 2774.6938 0 473.81808
# c1914d81-0367-4314-a1a8-f36ae62cf9c4 GG_bunny account.1e1038c5ca4648a0b5904f38ce8f4036 0 1 0 0 0 0 0 0 0 315.80585
# ...

# %%
match_ids = {1: 'c1914d81-0367-4314-a1a8-f36ae62cf9c4', 2: 'a8a4e194-d1d3-4b0e-8e93-0b6b19145140', 3: 'f10d398d-1eba-4eb1-a95f-1aa359da16b3', 4: 'c57785ae-d626-4ae7-acda-55769a308ca6', 5: 'd6f67b2f-9840-4403-a0f7-e5c589a4ea0f', 6: 'c040b89d-f6e2-4c43-930b-eaf6a85bc247', 7: '0a19f07a-3677-43af-b3ec-b36770b4a77c', 8: 'a2fd607d-7013-48c3-887c-567c6c040d6c', 9: 'af1e9b28-3c0e-4564-a01a-eda5c84a273c', 10: '99bb1865-c8cd-4428-b3bc-88766dc0dcf3', 11: '05ecad44-a92f-486b-8b28-6b1d3ead572b', 12: '079a197f-0dfb-4ea7-bd0e-6b9acb6e8901', 13: '1f3dc895-e401-433e-af52-094f99e260b3', 14: '7c162184-445d-4332-9ffd-855b177b2872', 15: '757b25e0-80de-
bee-954f-64acce7a817f', 63: 'd563303c-6a9c-4a3b-93a6-573e23fd8488', 64: 'b69747e9-35d8-4237-b7b7-7306c1f1983b', 65: 'bba22488-0af2-426a-9684-059f049bedbb', 66: '956e1aac-d3a9-4fb0-b272-4b553a0aad10', 67: 'c110f30b-766a-4f84-8c59-4c4ed290aebf', 68: '57f9205f-2f9a-4c84-a396-b256110bd268', 69: '32d610e0-0b4e-489d-92a2-beb768fc5f4d', 70: '7c64ffe0-0b6b-45b8-a409-1e0c6d44d356', 71: '377b9667-9a06-473a-b8f0-ce851e20826e', 72: 'a90214ff-ba82-4cf4-8e76-88a856198981', 73: 'a193fc5c-6ae8-4130-98a2-17d2e63e4f41', 74: 'b4106650-8a22-43fe-8295-6ce2877a636b', 75: '221c588a-e7dc-44a3-a07e-d4d0dff5f965', 76: '6457ee66-4ed4-478f-aceb-fada539194eb', 77: '80131a52-0301-42e2-8f64-284e8a22a0e7', 78: '9eaed105-2e80-4e91-9f92-47b34b61b1f3', 79: 'fb093400-efb1-4aac-92ba-18fef6345b38', 80: 'bcbe4567-9300-495b-a527-c40d69828bce', 81: '64847ab5-ea87-4c77-b5ed-73855be9a825', 82: 'bd9dc792-e0b5-46d6-9124-18a7295cafeb', 83: 'ee8776e4-b145-4438-8645-043aa10041c9', 84: 'f719b7ff-607f-40de-ac7a-c48b42337e69', 85: '1de12e0f-00a6-4e8e-a092-6d2fa0530ce1', 86: '80a7f00a-3712-49c0-ba95-89224908b652', 87: 'c4daefff-ecd8-44ad-85b0-df0c36056284'}

# %%
for i in a.values() : 
    print(i)
# Out:
# c1914d81-0367-4314-a1a8-f36ae62cf9c4
# a8a4e194-d1d3-4b0e-8e93-0b6b19145140
# f10d398d-1eba-4eb1-a95f-1aa359da16b3
# c57785ae-d626-4ae7-acda-55769a308ca6
# d6f67b2f-9840-4403-a0f7-e5c589a4ea0f
# c040b89d-f6e2-4c43-930b-eaf6a85bc247
# 0a19f07a-3677-43af-b3ec-b36770b4a77c
# a2fd607d-7013-48c3-887c-567c6c040d6c
# af1e9b28-3c0e-4564-a01a-eda5c84a273c
# 99bb1865-c8cd-4428-b3bc-88766dc0dcf3
# 05ecad44-a92f-486b-8b28-6b1d3ead572b
# 079a197f-0dfb-4ea7-bd0e-6b9acb6e8901
# 1f3dc895-e401-433e-af52-094f99e260b3
# 7c162184-445d-4332-9ffd-855b177b2872
# 757b25e0-80de-4990-9e8e-efc51bc680b2
# f398ca80-e1be-4369-a8eb-ed30fe09bf25
# e6e6aa6d-e6d7-44c6-bf74-350eebfe7f08
# 71e07ba7-01e8-40de-b103-616c4545b927
# b113d623-eb4e-4d79-aeea-c3d0dbe38ab2
# 1cd9ee4d-5d99-4162-9d7b-eddf445b12c1
# 66c2ebe4-d284-403b-9427-94aab2068f99
# 3889560f-0583-445e-ab92-385a0ec8f53b
# 57d70afd-af2a-48f0-b7d9-5cd6ef2f6907
# 53266b83-2020-46ae-bf54-2d941962d71e
# ed24b25d-534e-4c1b-a179-6b852ee6f620
# ...

# %%
search_player_match(key, match_id)
# Out:
# ('12471124-bec9-423e-8aca-353df6929a76',
#  '2023-06-17T14:49:53Z',
#  'duo',
#  'Savage_Main',
#  1427,
#  'official',
#  'https://telemetry-cdn.pubg.com/bluehole-pubg/kakao/2023/06/17/15/15/d1a00e8d-0d21-11ee-a53b-86b72d64fa18-telemetry.json')

# %%
from django.shortcuts import render
from .models import Match
import requests

def save_match_to_table(request):
    key = "your_api_key"  # PUBG API 키
    match_id = "your_match_id"  # 검색할 매치 ID

    url = f"https://api.pubg.com/shards/steam/matches/{match_id}"
    headers = {
        "Authorization": key,
        "Accept": "application/vnd.api+json"
    }
    response = requests.get(url, headers=headers)
    if response.status_code == 200 : 
        result = response.json()
        for i in range(len(result['included'])) : 
            if result['included'][i]['type'] == 'asset' : 
                matchId = result['data']['id']
                createAt = result['data']['attributes']['createdAt']
                gameMode = result['data']['attributes']['gameMode']
                mapname = result['data']['attributes']['mapName']
                duration = result['data']['attributes']['duration']
                match_type = result['data']['attributes']['matchType']
                asset_url = result['included'][i]['attributes']['URL']

                # Match 테이블에 데이터 저장
                match = Match(
                    match_id=matchId,
                    created_at=createAt,
                    game_mode=gameMode,
                    map_name=mapname,
                    duration=duration,
                    match_type=match_type,
                    asset_url=asset_url
                )
                match.save()

    return render(request, 'template_name.html')
# Out:
# {'data': {'type': 'match',
#   'id': '12471124-bec9-423e-8aca-353df6929a76',
#   'attributes': {'stats': None,
#    'titleId': 'bluehole-pubg',
#    'shardId': 'kakao',
#    'duration': 1427,
#    'gameMode': 'duo',
#    'tags': None,
#    'mapName': 'Savage_Main',
#    'isCustomMatch': False,
#    'matchType': 'official',
#    'seasonState': 'progress',
#    'createdAt': '2023-06-17T14:49:53Z'},
#   'relationships': {'rosters': {'data': [{'type': 'roster',
#       'id': '289cb882-f6f1-4db1-b22f-3e5a6fd51b7d'},
#      {'type': 'roster', 'id': 'c7203715-3296-42df-bf9c-6998c88265e1'},
#      {'type': 'roster', 'id': '2e71794f-5cf8-40e8-ad8b-3adae02fbfec'},
#      {'type': 'roster', 'id': 'ce4d2857-2d25-4f81-a75e-1671e9a08ea9'},
#      {'type': 'roster', 'id': '10ef9ec3-c2a8-48d9-8e83-f14db451ac03'},
#      {'type': 'roster', 'id': 'ba01e42a-1c4c-4b27-9f87-c16aeb2c39ed'},
#      {'type': 'roster', 'id': 'd7c797ec-5e82-4bd2-a32a-f0da95dd63e6'},
# ...

# %%
for i in range(len(result['included'])) : 
    if result['included'][i]['type'] == 'asset' : 
        print(result['included'][i])
        print(f"{i}")
# Out:
# {'type': 'asset', 'id': 'd1a00e8d-0d21-11ee-a53b-86b72d64fa18', 'attributes': {'name': 'telemetry', 'description': '', 'createdAt': '2023-06-17T15:15:39Z', 'URL': 'https://telemetry-cdn.pubg.com/bluehole-pubg/kakao/2023/06/17/15/15/d1a00e8d-0d21-11ee-a53b-86b72d64fa18-telemetry.json'}}
# 115

# %%
# Out:
# 'participant'
